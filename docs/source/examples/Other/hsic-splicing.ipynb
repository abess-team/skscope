# %%
import numpy as np
import jax.numpy as jnp
from scope import ScopeSolver
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.metrics.pairwise import rbf_kernel

# %% [markdown]
# # Non-linear feature selection via HSIC-Splicing
# In some applications, we want to find relevant predictors where the relationship between the response $y$ with them are allowed to be non-linear. Traditional variable selection techniques in linear model can not be applied directly.
# In this example, we introduce a method adapted from [Yamada et al.](http://www.ms.k.u-tokyo.ac.jp/sugi/2014/HSICLasso.pdf) to identify relevant features $X_k, k\in[p]$ from $X^{n\times p}$ which has nonlinear dependence of $y\in\mathbb{R}^n$.
# Specifically, we consider the following sparse optimization:
# $$\min_{\alpha\in\mathbb{R}^p} \left\|\bar{L}-\sum_{k=1}^p\alpha_k\bar{K}^{(k)}\right\|_F^2,\quad\text{ s.t. } \alpha\geq 0, \|\alpha\|_0\leq s$$
# where $\bar{K}^{(k)}=\Gamma K^{(k)}\Gamma\in\mathbb{R}^{n\times n}$, $\bar{L}=\Gamma L\Gamma\in\mathbb{R}^{n\times n}$ are centralized Gram matrices and $\Gamma=I_n-n^{-1}1_n1_n^{\top}\in\mathbb{R}^{n\times n}$.
# The matrices $K_{i,j}^{(k)}=K(X_{i,k}, X_{j,k})$, $L_{i,j}=L(y_i, y_j)$ are generated via kernel $K$ and $L$ respectively.
# In the following, we choose both $K$ and $L$ to be Gaussian kernel function.

# %% [markdown]
# Note that ``scope`` can not be directlty used to solve the above optimization due to the presence of the positive constraint $\alpha\geq 0$. Instead, we eliminate this constraint via reparametrization, i.e., we optimize the (component-wise) absolute value of $\alpha$ directly. The following function ``hsic`` shows the method of our proposal and two simulation experiments will be performed later to validate its effectiveness.

# %%
def hsic(X, y, sparsity, gamma_x=0.7, gamma_y=0.7):
    n, p = X.shape
    Gamma = np.eye(n) - np.ones((n, 1)) @ np.ones((1, n)) / n
    L = rbf_kernel(y.reshape(-1, 1), gamma=gamma_y)
    L_bar = Gamma @ L @ Gamma
    response = L_bar.reshape(-1)
    K_bar = np.zeros((n**2, p))
    for k in range(p):
        x = X[:, k]
        tmp = rbf_kernel(x.reshape(-1, 1), gamma=gamma_x)
        K_bar[:, k] = (Gamma @ tmp @ Gamma).reshape(-1)
    covariate = K_bar

    def custom_objective(alpha):
        loss = jnp.mean((response - covariate @ jnp.abs(alpha)) ** 2)
        return loss
    
    solver = ScopeSolver(p, sparsity=sparsity)
    alpha = solver.solve(custom_objective)
    return alpha

# %% [markdown]
# ## 1. Additive model:
# First, we consider the following non-linear additive model, that is, the relationship between response $y$ and predictors $X_i$ is non-linear but there exists no interaction among predictors.
# In this example, we randomly generate $n=500$ samples and each sample has $p=1000$ predictors. The reponse depends on the first $s=4$ predictors only and the specific relation is depicted as follows:
# $$y=-2\sin(2X_1)+X_2^2+X_3+\exp(-X_4)+\epsilon.$$

# %%
# data generation
n, p, s = 500, 1000, 4
rng = np.random.default_rng(0)
X = rng.normal(0, 1, (n, p))
noise = rng.normal(0, 1, n)
y = -2 * np.sin(2 * X[:, 0]) + X[:, 1] ** 2 + X[:, 2] + np.exp(- X[:, 3]) + noise

# %% [markdown]
# To illustrate the non-linear relationship, we visualize the marginal relationship between the response $y$ and the first $4$ predictors $X_i,i=1,2,3,4$ respectively.
# The corresponding scatter plots is shown and $4$ polynomial regressions are fit to indicate the non-linear effects.

# %%
# marginal relation plot
fig, axes = plt.subplots(1, 4, figsize=(12,3))
for i in range(len(axes)):
    sns.regplot(x=X[:, i], y=y, order=2, ci=None, ax=axes[i],
                scatter_kws={'color': 'k', 's': 1},
                line_kws={'linewidth': 1, 'color': 'r'})
    axes[i].set_ylim(-10, 20)
    axes[i].set_xlabel('X{}'.format(i+1))
axes[0].set_ylabel('y')
plt.tight_layout()

# %% [markdown]
# The following result shows that ``scope`` can exactly select the relevant predictors in this setting.

# %%
# variable selection
alpha = hsic(X, y, s)
np.nonzero(alpha)[0]
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# ## 2. Non-additive model:
# Beyond the additive model, we here allow interaction effects among predictors (e.g. between $X_1$ and $X_2$) specified as follows:
# $$y=X_1\exp(2X_2)+X_3^2+\epsilon.$$
#
# Similarly, we set $n=500, p=1000$ but only $s=3$ relevant predictors are included in the model.

# %%
# data generation
n, p, s = 500, 1000, 3
rng = np.random.default_rng(1)
X = rng.normal(0, 1, (n, p))
noise = rng.normal(0, 1, n)
y = X[:, 0] * np.exp(2 * X[:, 1]) + X[:, 2] ** 2 + noise

# %% [markdown]
# The following figure shows the marginal relationship betweeen $y$ and $X_i, i=1,2,3$.

# %%
# marginal relation plot
fig, axes = plt.subplots(1, 3, figsize=(10,3))
for i in range(len(axes)):
    sns.regplot(x=X[:, i], y=y, order=2, ci=None, ax=axes[i],
                scatter_kws={'color': 'k', 's': 1},
                line_kws={'linewidth': 1, 'color': 'r'})
    axes[i].set_ylim(-50, 50)
    axes[i].set_xlabel('X{}'.format(i+1))
axes[0].set_ylabel('y')    
plt.tight_layout()

# %% [markdown]
# Despite of the interaction between $X_1$ and $X_2$, ``scope`` still correctly selects the true relevant predictors.

# %%
# variable selection
alpha = hsic(X, y, s)
np.nonzero(alpha)[0]
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Reference
# - Yamada M, Jitkrittum W, Sigal L, et al. High-dimensional feature selection by feature-wise kernelized lasso[J]. Neural computation, 2014, 26(1): 185-207.
